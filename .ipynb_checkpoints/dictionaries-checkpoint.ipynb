# %%
##Dictionary can not be sorted
fructs = {'name':'apple', 'price':2.2, 'collor':'red'}

# %%
fructs
# Out:
# {'name': 'apple', 'price': 2.2, 'collor': 'red'}

# %%
fruct['name']
# Out:
# 'apple'

# %% [markdown]
# ____

# %%
fructs = {
          'name':'apple', 
          'group':[1,2,3], 
          'sub_groups':{
                        'where':'tree', 
                        'why':'vitamin'
          }
}

# %%
fructs['group']
# Out:
# [1, 2, 3]

# %%
fructs['group'][1]
# Out:
# 2

# %%
fructs['sub_groups']
# Out:
# {'where': 'tree', 'why': 'vitamin'}

# %%
fructs['sub_groups']['where']
# Out:
# 'tree'

# %% [markdown]
# ____

# %%
d = {'k1':100, 'k2':200 }

# %%
d['k3'] = 'NEW VALUE'

# %%
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 'NEW VALUE'}

# %%
d['k1']  = 'CHANGED VALUE'

# %%
d
# Out:
# {'k1': 'CHANGED VALUE', 'k2': 200, 'k3': 'NEW VALUE'}
