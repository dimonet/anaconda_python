# %%
my_list = [1,2,3]

# %%
my_list = ['string', 100, 23.2]

# %%
len(my_list)
# Out:
# 3

# %%
my_list[0]
# Out:
# 'string'

# %%
my_list[1:]
# Out:
# [100, 23.2]

# %% [markdown]
# ______________________________

# %%
nested_list = [1,1,[1,2]]

# %%
nested_list[2][1]
# Out:
# 2

# %% [markdown]
# __________

# %%
new_list = ['a', 'b']

# %%
all_lists = my_list + new_list

# %%
all_lists
# Out:
# ['string', 100, 23.2, 'a', 'b']

# %%
all_lists[0] = 'str'   # diff with string, list can be changed

# %%
all_lists
# Out:
# ['str', 100, 23.2, 'a', 'b']

# %%
new_list.append('s') # add new element in the lost

# %%
new_list
# Out:
# ['a', 'b', 's']

# %% [markdown]
# ---------------------------

# %%
new_list.pop()
# Out:
# 's'

# %%
new_list
# Out:
# ['a', 'b']

# %%
new_list.pop()
# Out:
# 'b'

# %%
new_list
# Out:
# ['a']

# %% [markdown]
# ________________________________________________________

# %%
new_list = ['a', 'b', 's']

# %%
new_list.pop(1)
# Out:
# 'b'

# %%
new_list
# Out:
# ['a', 's']

# %% [markdown]
# ________________________________

# %%
new_list = ['b', 'c', 'a']

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c']

# %%
new_sorted_list = new_list.sort()  # it does not work, the 'sort' returns nothing

# %%
type(new_sorted_list)
# Out:
# NoneType

# %% [markdown]
# _______________________________________________

# %%
# if you wont to sort the list should be do it as is:

# %%
new_list.sort()
new_sorted_list = new_list

# %%
new_sorted_list
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ________________________________________
