# %%
a = 'qwerty'

# %%
a[2]
# Out:
# 'e'

# %%
a[-2]
# Out:
# 't'

# %%
a[2:]
# Out:
# 'erty'

# %%
a[:3]
# Out:
# 'qwe'

# %%
a[2:]
# Out:
# 'erty'

# %%
a[1:3]
# Out:
# 'we'

# %%
a[::]  # full string
# Out:
# 'qwerty'

# %%
a[::2]  # step size 2
# Out:
# 'qet'

# %%
a[::-1]
# Out:
# 'ytrewq'

# %% [markdown]
# String Properties and Methods

# %%
x = 'Hello World'

# %%
x = x + ' It is beautful'

# %%
x
# Out:
# 'Hello World It is beautful It is beautful'

# %%
'2' + '3'
# Out:
# '23'

# %% [markdown]
# ________________

# %%
x = 'Hello World. How are your'

# %%
x.split()
# Out:
# ['Hello', 'World.', 'How', 'are', 'your']

# %%
x = 'Hello:World:How:are:your'

# %%
x.split(':')
# Out:
# ['Hello', 'World', 'How', 'are', 'your']

# %% [markdown]
# ____________

# %%
print('This uis a string {}'.format('INSERTED'))
# Out:
# This uis a string INSERTED

# %%
print('The {} {} {}'.format('fox','brown','quick'))
# Out:
# The fox brown quick

# %%
print('The {0} {0} {0}'.format('fox','brown','quick'))
# Out:
# The fox fox fox

# %%
print('The {f} {b} {q}'.format(f='fox', b='brown', q='quick'))
# Out:
# The fox brown quick

# %% [markdown]
# ___________________

# %%
result = 111/777

# %%
result
# Out:
# 0.14285714285714285

# %%
print("The result was {r:1.3f}".format(r=result))
# Out:
# The result was 0.143

# %%
print("The result was {r:20.3f}".format(r=result))
# Out:
# The result was                0.143

# %% [markdown]
# _________

# %% [raw]
# name = 'Jose'

# %%
print(f'Hello, {name}')
# Out:
# Hello, Jose

# %% [markdown]
# ______

# %%
print('{} {}{}'.format('Python','rules','!'))
# Out:
# Python rules!
